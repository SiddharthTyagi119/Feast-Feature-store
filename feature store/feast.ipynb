# %% [markdown]
# # Prepare data set and store in parquet format

# %%
import pandas as pd

# %%
data = pd.read_csv('diabetes.csv')
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI
# 0            1       85             66             29        0  26.6  \
# 1            8      183             64              0        0  23.3
# 2            1       89             66             23       94  28.1
# 3            0      137             40             35      168  43.1
# 4            5      116             74              0        0  25.6
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.351   31        0
# 1                     0.672   32        1
# 2                     0.167   21        0
# 3                     2.288   33        1
# 4                     0.201   30        0

# %%
#target and features variables
predictors_df = data.loc[:,data.columns!='Outcome']
target_df = data['Outcome']
predictors_df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI
# 0            1       85             66             29        0  26.6  \
# 1            8      183             64              0        0  23.3
# 2            1       89             66             23       94  28.1
# 3            0      137             40             35      168  43.1
# 4            5      116             74              0        0  25.6
#
#    DiabetesPedigreeFunction  Age
# 0                     0.351   31
# 1                     0.672   32
# 2                     0.167   21
# 3                     2.288   33
# 4                     0.201   30

# %% [markdown]
# # Create timestamp to be added as event_timestamp column in the data set.

# %%
timestamps = pd.date_range(end = pd.Timestamp.now(),
                           periods = len(data),freq = 'D').to_frame(name = 'event_timestamp', index = False)
timestamps
# Out:
#                event_timestamp
# 0   2021-05-08 14:31:28.830917
# 1   2021-05-09 14:31:28.830917
# 2   2021-05-10 14:31:28.830917
# 3   2021-05-11 14:31:28.830917
# 4   2021-05-12 14:31:28.830917
# ..                         ...
# 762 2023-06-09 14:31:28.830917
# 763 2023-06-10 14:31:28.830917
# 764 2023-06-11 14:31:28.830917
# 765 2023-06-12 14:31:28.830917
# 766 2023-06-13 14:31:28.830917
#
# [767 rows x 1 columns]

# %% [markdown]
# # add event_timestamp column to the predictors and target dataframes

# %%
predictors_df = pd.concat(objs = [predictors_df, timestamps], axis = 1)
target_df = pd.concat(objs = [target_df, timestamps], axis =1)
predictors_df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI
# 0            1       85             66             29        0  26.6  \
# 1            8      183             64              0        0  23.3
# 2            1       89             66             23       94  28.1
# 3            0      137             40             35      168  43.1
# 4            5      116             74              0        0  25.6
#
#    DiabetesPedigreeFunction  Age            event_timestamp
# 0                     0.351   31 2021-05-08 14:31:28.830917
# 1                     0.672   32 2021-05-09 14:31:28.830917
# 2                     0.167   21 2021-05-10 14:31:28.830917
# 3                     2.288   33 2021-05-11 14:31:28.830917
# 4                     0.201   30 2021-05-12 14:31:28.830917

# %%
target_df.head()
# Out:
#    Outcome            event_timestamp
# 0        0 2021-05-08 14:31:28.830917
# 1        1 2021-05-09 14:31:28.830917
# 2        0 2021-05-10 14:31:28.830917
# 3        1 2021-05-11 14:31:28.830917
# 4        0 2021-05-12 14:31:28.830917

# %% [markdown]
# # Create a patientID column to uniquely identify records with patientID and timestamp field together.

# %%
dataLen = len(data)
idsList = list(range(dataLen))
#idsList

# %%
#idsList
idsList = list(range(dataLen))

# %%
#patient_ids to uniquely identify the record
patient_ids = pd.DataFrame(data = idsList, columns = ['patient_id'])
patient_ids
# Out:
#      patient_id
# 0             0
# 1             1
# 2             2
# 3             3
# 4             4
# ..          ...
# 762         762
# 763         763
# 764         764
# 765         765
# 766         766
#
# [767 rows x 1 columns]

# %%
#concat the patient id to both the df i.e target and fetures
predictors_df = pd.concat(objs = [predictors_df, patient_ids], axis = 1)
target_df = pd.concat(objs = [target_df, patient_ids], axis =1)

# %%
predictors_df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI
# 0            1       85             66             29        0  26.6  \
# 1            8      183             64              0        0  23.3
# 2            1       89             66             23       94  28.1
# 3            0      137             40             35      168  43.1
# 4            5      116             74              0        0  25.6
#
#    DiabetesPedigreeFunction  Age            event_timestamp  patient_id
# 0                     0.351   31 2021-05-08 14:31:28.830917           0
# 1                     0.672   32 2021-05-09 14:31:28.830917           1
# 2                     0.167   21 2021-05-10 14:31:28.830917           2
# 3                     2.288   33 2021-05-11 14:31:28.830917           3
# 4                     0.201   30 2021-05-12 14:31:28.830917           4

# %%
predictors_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 767 entries, 0 to 766
# Data columns (total 10 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               767 non-null    int64
#  1   Glucose                   767 non-null    int64
#  2   BloodPressure             767 non-null    int64
#  3   SkinThickness             767 non-null    int64
#  4   Insulin                   767 non-null    int64
#  5   BMI                       767 non-null    float64
#  6   DiabetesPedigreeFunction  767 non-null    float64
#  7   Age                       767 non-null    int64
#  8   event_timestamp           767 non-null    datetime64[ns]
#  9   patient_id                767 non-null    int64
# dtypes: datetime64[ns](1), float64(2), int64(7)
# memory usage: 60.0 KB

# %%
#converting the df into parquet
predictors_df.to_parquet(path='predictors_df.parquet')
target_df.to_parquet(path='target_df.parquet')

# %%
# !pip install feast
# Out:
# Collecting feast
#   Downloading feast-0.31.1-py2.py3-none-any.whl (4.6 MB)
#      ---------------------------------------- 0.0/4.6 MB ? eta -:--:--
#      ---------------------------------------- 0.0/4.6 MB 991.0 kB/s eta 0:00:05
#      -- ------------------------------------- 0.2/4.6 MB 3.0 MB/s eta 0:00:02
#      --- ------------------------------------ 0.4/4.6 MB 2.9 MB/s eta 0:00:02
#      ----- ---------------------------------- 0.6/4.6 MB 3.1 MB/s eta 0:00:02
#      ------ --------------------------------- 0.8/4.6 MB 3.4 MB/s eta 0:00:02
#      -------- ------------------------------- 0.9/4.6 MB 3.5 MB/s eta 0:00:02
#      --------- ------------------------------ 1.1/4.6 MB 3.4 MB/s eta 0:00:02
#      ----------- ---------------------------- 1.3/4.6 MB 3.4 MB/s eta 0:00:01
#      ------------ --------------------------- 1.4/4.6 MB 3.3 MB/s eta 0:00:01
#      -------------- ------------------------- 1.6/4.6 MB 3.4 MB/s eta 0:00:01
#      --------------- ------------------------ 1.8/4.6 MB 3.5 MB/s eta 0:00:01
#      ---------------- ----------------------- 1.9/4.6 MB 3.5 MB/s eta 0:00:01
#      ------------------ --------------------- 2.1/4.6 MB 3.5 MB/s eta 0:00:01
#      --------------------- ------------------ 2.4/4.6 MB 3.6 MB/s eta 0:00:01
#      ----------------------- ---------------- 2.7/4.6 MB 3.5 MB/s eta 0:00:01
#      ------------------------ --------------- 2.8/4.6 MB 3.4 MB/s eta 0:00:01
#      -------------------------- ------------- 3.0/4.6 MB 3.3 MB/s eta 0:00:01
#      --------------------------- ------------ 3.1/4.6 MB 3.2 MB/s eta 0:00:01
#      ---------------------------- ----------- 3.2/4.6 MB 3.1 MB/s eta 0:00:01
#      ----------------------------- ---------- 3.3/4.6 MB 3.0 MB/s eta 0:00:01
#      ----------------------------- ---------- 3.4/4.6 MB 2.9 MB/s eta 0:00:01
#      ------------------------------ --------- 3.5/4.6 MB 2.9 MB/s eta 0:00:01
#      -------------------------------- ------- 3.7/4.6 MB 2.8 MB/s eta 0:00:01
#      --------------------------------- ------ 3.8/4.6 MB 2.8 MB/s eta 0:00:01
#      ---------------------------------- ----- 3.9/4.6 MB 2.8 MB/s eta 0:00:01
#      ---------------------------------- ----- 4.0/4.6 MB 2.7 MB/s eta 0:00:01
#      ----------------------------------- ---- 4.1/4.6 MB 2.6 MB/s eta 0:00:01
#      ------------------------------------ --- 4.1/4.6 MB 2.6 MB/s eta 0:00:01
#      ------------------------------------- -- 4.2/4.6 MB 2.5 MB/s eta 0:00:01
#      ------------------------------------- -- 4.3/4.6 MB 2.5 MB/s eta 0:00:01
#      -------------------------------------- - 4.4/4.6 MB 2.4 MB/s eta 0:00:01
#      -------------------------------------- - 4.4/4.6 MB 2.4 MB/s eta 0:00:01
#      ---------------------------------------  4.5/4.6 MB 2.3 MB/s eta 0:00:01
#      ---------------------------------------  4.6/4.6 MB 2.3 MB/s eta 0:00:01
#      ---------------------------------------- 4.6/4.6 MB 2.3 MB/s eta 0:00:00
# Requirement already satisfied: httpx>=0.23.3 in c:\users\sairam\anaconda3\envs\mlops\lib\site-packages (from feast) (0.24.1)
# Collecting bowler
#   Downloading bowler-0.9.0-py3-none-any.whl (36 kB)
# Requirement already satisfied: protobuf<5,>3.20 in c:\users\sairam\anaconda3\envs\mlops\lib\site-packages (from feast) (4.23.2)
# Requirement already satisfied: tenacity<9,>=7 in c:\users\sairam\anaconda3\envs\mlops\lib\site-packages (from feast) (8.2.2)
# Requirement already satisfied: pyarrow<12,>=4 in c:\users\sairam\anaconda3\envs\mlops\lib\site-packages (from feast) (11.0.0)
# Requirement already satisfied: Jinja2<4,>=2 in c:\users\sairam\anaconda3\envs\mlops\lib\site-packages (from feast) (3.1.2)
# Collecting pandavro~=1.5.0
#   Downloading pandavro-1.5.2.tar.gz (3.8 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: tqdm<5,>=4 in c:\users\sairam\anaconda3\envs\mlops\lib\site-packages (from feast) (4.65.0)
# Requirement already satisfied: pygments<3,>=2.12.0 in c:\users\sairam\anaconda3\envs\mlops\lib\site-packages (from feast) (2.15.1)
# Requirement already satisfied: jsonschema in c:\users\sairam\anaconda3\envs\mlops\lib\site-packages (from feast) (4.17.3)
# Requirement already satisfied: pydantic<2,>=1 in c:\users\sairam\anaconda3\envs\mlops\lib\site-packages (from feast) (1.10.8)
# Collecting mmh3
#   Downloading mmh3-4.0.0-cp38-cp38-win_amd64.whl (31 kB)
# Requirement already satisfied: fastapi<1,>=0.68.0 in c:\users\sairam\anaconda3\envs\mlops\lib\site-packages (from feast) (0.95.2)
# Requirement already satisfied: colorama<1,>=0.3.9 in c:\users\sairam\anaconda3\envs\mlops\lib\site-packages (from feast) (0.4.6)
# Requirement already satisfied: dask>=2021.1.0 in c:\users\sairam\anaconda3\envs\mlops\lib\site-packages (from feast) (2023.5.0)
# Requirement already satisfied: requests in c:\users\sairam\anaconda3\envs\mlops\lib\site-packages (from feast) (2.31.0)
# Collecting typeguard==2.13.3
#   Downloading typeguard-2.13.3-py3-none-any.whl (17 kB)
# Collecting grpcio<2,>=1.47.0
#   Using cached grpcio-1.54.2-cp38-cp38-win_amd64.whl (4.1 MB)
# Collecting grpcio-reflection<2,>=1.47.0
#   Downloading grpcio_reflection-1.54.2-py3-none-any.whl (11 kB)
# Collecting pandas<2,>=1.4.3
#   Using cached pandas-1.5.3-cp38-cp38-win_amd64.whl (11.0 MB)
# Collecting fastavro<2,>=1.1.0
#   Downloading fastavro-1.7.4-cp38-cp38-win_amd64.whl (458 kB)
#      ---------------------------------------- 0.0/458.3 kB ? eta -:--:--
#      --------- ---------------------------- 112.6/458.3 kB 2.2 MB/s eta 0:00:01
#      ------------------ ------------------- 225.3/458.3 kB 2.3 MB/s eta 0:00:01
#      ---------------------------- --------- 337.9/458.3 kB 2.1 MB/s eta 0:00:01
#      -------------------------------------  450.6/458.3 kB 2.0 MB/s eta 0:00:01
#      -------------------------------------- 458.3/458.3 kB 1.8 MB/s eta 0:00:00
# Requirement already satisfied: numpy<3,>=1.22 in c:\users\sairam\anaconda3\envs\mlops\lib\site-packages (from feast) (1.24.3)
# Collecting proto-plus<2,>=1.20.0
#   Downloading proto_plus-1.22.2-py3-none-any.whl (47 kB)
#      ---------------------------------------- 0.0/47.9 kB ? eta -:--:--
#      ---------------------------------------- 47.9/47.9 kB 1.2 MB/s eta 0:00:00
# Requirement already satisfied: SQLAlchemy[mypy]<2,>1 in c:\users\sairam\anaconda3\envs\mlops\lib\site-packages (from feast) (1.4.48)
# Requirement already satisfied: click<9.0.0,>=7.0.0 in c:\users\sairam\anaconda3\envs\mlops\lib\site-packages (from feast) (8.1.3)
# Requirement already satisfied: uvicorn[standard]<1,>=0.14.0 in c:\users\sairam\anaconda3\envs\mlops\lib\site-packages (from feast) (0.22.0)
# Collecting dill~=0.3.0
#   Using cached dill-0.3.6-py3-none-any.whl (110 kB)
# Requirement already satisfied: tabulate<1,>=0.8.0 in c:\users\sairam\anaconda3\envs\mlops\lib\site-packages (from feast) (0.9.0)
# Requirement already satisfied: PyYAML<7,>=5.4.0 in c:\users\sairam\anaconda3\envs\mlops\lib\site-packages (from feast) (6.0)
# Requirement already satisfied: toml<1,>=0.10.0 in c:\users\sairam\anaconda3\envs\mlops\lib\site-packages (from feast) (0.10.2)
# Requirement already satisfied: partd>=1.2.0 in c:\users\sairam\anaconda3\envs\mlops\lib\site-packages (from dask>=2021.1.0->feast) (1.4.0)
# Requirement already satisfied: toolz>=0.10.0 in c:\users\sairam\anaconda3\envs\mlops\lib\site-packages (from dask>=2021.1.0->feast) (0.12.0)
# Requirement already satisfied: fsspec>=2021.09.0 in c:\users\sairam\anaconda3\envs\mlops\lib\site-packages (from dask>=2021.1.0->feast) (2023.5.0)
# Requirement already satisfied: cloudpickle>=1.5.0 in c:\users\sairam\anaconda3\envs\mlops\lib\site-packages (from dask>=2021.1.0->feast) (2.2.1)
# Requirement already satisfied: importlib-metadata>=4.13.0 in c:\users\sairam\anaconda3\envs\mlops\lib\site-packages (from dask>=2021.1.0->feast) (6.0.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\sairam\anaconda3\envs\mlops\lib\site-packages (from dask>=2021.1.0->feast) (23.0)
# Requirement already satisfied: starlette<0.28.0,>=0.27.0 in c:\users\sairam\anaconda3\envs\mlops\lib\site-packages (from fastapi<1,>=0.68.0->feast) (0.27.0)
# Requirement already satisfied: idna in c:\users\sairam\anaconda3\envs\mlops\lib\site-packages (from httpx>=0.23.3->feast) (3.4)
# Requirement already satisfied: sniffio in c:\users\sairam\anaconda3\envs\mlops\lib\site-packages (from httpx>=0.23.3->feast) (1.2.0)
# Requirement already satisfied: certifi in c:\users\sairam\anaconda3\envs\mlops\lib\site-packages (from httpx>=0.23.3->feast) (2023.5.7)
# Requirement already satisfied: httpcore<0.18.0,>=0.15.0 in c:\users\sairam\anaconda3\envs\mlops\lib\site-packages (from httpx>=0.23.3->feast) (0.17.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\sairam\anaconda3\envs\mlops\lib\site-packages (from Jinja2<4,>=2->feast) (2.1.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\sairam\anaconda3\envs\mlops\lib\site-packages (from pandas<2,>=1.4.3->feast) (2023.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\sairam\anaconda3\envs\mlops\lib\site-packages (from pandas<2,>=1.4.3->feast) (2.8.2)
# Requirement already satisfied: six>=1.9 in c:\users\sairam\anaconda3\envs\mlops\lib\site-packages (from pandavro~=1.5.0->feast) (1.16.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\sairam\anaconda3\envs\mlops\lib\site-packages (from pydantic<2,>=1->feast) (4.5.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\sairam\anaconda3\envs\mlops\lib\site-packages (from SQLAlchemy[mypy]<2,>1->feast) (2.0.2)
# Collecting mypy>=0.910
#   Downloading mypy-1.3.0-cp38-cp38-win_amd64.whl (8.9 MB)
#      ---------------------------------------- 0.0/8.9 MB ? eta -:--:--
#       --------------------------------------- 0.1/8.9 MB 2.2 MB/s eta 0:00:05
#       --------------------------------------- 0.2/8.9 MB 2.5 MB/s eta 0:00:04
#      - -------------------------------------- 0.3/8.9 MB 2.4 MB/s eta 0:00:04
#      -- ------------------------------------- 0.5/8.9 MB 2.2 MB/s eta 0:00:04
#      -- ------------------------------------- 0.6/8.9 MB 2.3 MB/s eta 0:00:04
#      -- ------------------------------------- 0.7/8.9 MB 2.3 MB/s eta 0:00:04
#      --- ------------------------------------ 0.8/8.9 MB 2.3 MB/s eta 0:00:04
#      --- ------------------------------------ 0.8/8.9 MB 2.2 MB/s eta 0:00:04
#      ---- ----------------------------------- 0.9/8.9 MB 2.1 MB/s eta 0:00:04
#      ---- ----------------------------------- 1.0/8.9 MB 2.0 MB/s eta 0:00:05
#      ---- ----------------------------------- 1.1/8.9 MB 2.0 MB/s eta 0:00:04
#      ----- ---------------------------------- 1.2/8.9 MB 2.0 MB/s eta 0:00:04
#      ----- ---------------------------------- 1.3/8.9 MB 2.1 MB/s eta 0:00:04
#      ------ --------------------------------- 1.4/8.9 MB 2.1 MB/s eta 0:00:04
#      ------ --------------------------------- 1.5/8.9 MB 2.1 MB/s eta 0:00:04
#      ------- -------------------------------- 1.6/8.9 MB 2.1 MB/s eta 0:00:04
#      ------- -------------------------------- 1.8/8.9 MB 2.1 MB/s eta 0:00:04
#      -------- ------------------------------- 1.9/8.9 MB 2.2 MB/s eta 0:00:04
#      --------- ------------------------------ 2.1/8.9 MB 2.2 MB/s eta 0:00:04
#      --------- ------------------------------ 2.2/8.9 MB 2.2 MB/s eta 0:00:04
#      ---------- ----------------------------- 2.4/8.9 MB 2.2 MB/s eta 0:00:03
#      ----------- ---------------------------- 2.5/8.9 MB 2.2 MB/s eta 0:00:03
#      ------------ --------------------------- 2.7/8.9 MB 2.3 MB/s eta 0:00:03
#      ------------ --------------------------- 2.8/8.9 MB 2.2 MB/s eta 0:00:03
#      ------------- -------------------------- 3.0/8.9 MB 2.3 MB/s eta 0:00:03
#      ------------- -------------------------- 3.1/8.9 MB 2.3 MB/s eta 0:00:03
#      -------------- ------------------------- 3.3/8.9 MB 2.3 MB/s eta 0:00:03
#      --------------- ------------------------ 3.5/8.9 MB 2.4 MB/s eta 0:00:03
#      ---------------- ----------------------- 3.7/8.9 MB 2.4 MB/s eta 0:00:03
#      ----------------- ---------------------- 3.8/8.9 MB 2.4 MB/s eta 0:00:03
#      ----------------- ---------------------- 4.0/8.9 MB 2.4 MB/s eta 0:00:03
#      ------------------ --------------------- 4.1/8.9 MB 2.5 MB/s eta 0:00:02
#      ------------------- -------------------- 4.3/8.9 MB 2.5 MB/s eta 0:00:02
#      ------------------- -------------------- 4.4/8.9 MB 2.5 MB/s eta 0:00:02
#      -------------------- ------------------- 4.5/8.9 MB 2.5 MB/s eta 0:00:02
#      -------------------- ------------------- 4.7/8.9 MB 2.5 MB/s eta 0:00:02
#      --------------------- ------------------ 4.8/8.9 MB 2.5 MB/s eta 0:00:02
#      --------------------- ------------------ 4.9/8.9 MB 2.5 MB/s eta 0:00:02
#      ---------------------- ----------------- 5.0/8.9 MB 2.5 MB/s eta 0:00:02
#      ----------------------- ---------------- 5.2/8.9 MB 2.5 MB/s eta 0:00:02
#      ----------------------- ---------------- 5.3/8.9 MB 2.5 MB/s eta 0:00:02
#      ------------------------ --------------- 5.4/8.9 MB 2.5 MB/s eta 0:00:02
#      ------------------------ --------------- 5.6/8.9 MB 2.5 MB/s eta 0:00:02
#      ------------------------- -------------- 5.7/8.9 MB 2.6 MB/s eta 0:00:02
#      -------------------------- ------------- 5.9/8.9 MB 2.5 MB/s eta 0:00:02
#      -------------------------- ------------- 5.9/8.9 MB 2.5 MB/s eta 0:00:02
#      --------------------------- ------------ 6.1/8.9 MB 2.5 MB/s eta 0:00:02
#      --------------------------- ------------ 6.2/8.9 MB 2.5 MB/s eta 0:00:02
#      ---------------------------- ----------- 6.3/8.9 MB 2.5 MB/s eta 0:00:02
#      ---------------------------- ----------- 6.5/8.9 MB 2.6 MB/s eta 0:00:01
#      ----------------------------- ---------- 6.6/8.9 MB 2.6 MB/s eta 0:00:01
#      ------------------------------ --------- 6.7/8.9 MB 2.6 MB/s eta 0:00:01
#      ------------------------------ --------- 6.8/8.9 MB 2.6 MB/s eta 0:00:01
#      ------------------------------- -------- 6.9/8.9 MB 2.5 MB/s eta 0:00:01
#      ------------------------------- -------- 7.1/8.9 MB 2.6 MB/s eta 0:00:01
#      -------------------------------- ------- 7.3/8.9 MB 2.6 MB/s eta 0:00:01
#      --------------------------------- ------ 7.5/8.9 MB 2.6 MB/s eta 0:00:01
#      ---------------------------------- ----- 7.6/8.9 MB 2.6 MB/s eta 0:00:01
#      ----------------------------------- ---- 7.8/8.9 MB 2.6 MB/s eta 0:00:01
#      ------------------------------------ --- 8.1/8.9 MB 2.7 MB/s eta 0:00:01
#      ------------------------------------- -- 8.3/8.9 MB 2.7 MB/s eta 0:00:01
#      ------------------------------------- -- 8.4/8.9 MB 2.7 MB/s eta 0:00:01
#      -------------------------------------- - 8.5/8.9 MB 2.7 MB/s eta 0:00:01
#      -------------------------------------- - 8.6/8.9 MB 2.7 MB/s eta 0:00:01
#      ---------------------------------------  8.8/8.9 MB 2.7 MB/s eta 0:00:01
#      ---------------------------------------  8.8/8.9 MB 2.7 MB/s eta 0:00:01
#      ---------------------------------------  8.9/8.9 MB 2.7 MB/s eta 0:00:01
#      ---------------------------------------- 8.9/8.9 MB 2.6 MB/s eta 0:00:00
# Collecting sqlalchemy2-stubs
#   Downloading sqlalchemy2_stubs-0.0.2a34-py3-none-any.whl (191 kB)
#      ---------------------------------------- 0.0/191.6 kB ? eta -:--:--
#      -------------- ------------------------ 71.7/191.6 kB 2.0 MB/s eta 0:00:01
#      ---------------------------- --------- 143.4/191.6 kB 1.7 MB/s eta 0:00:01
#      ------------------------------------ - 184.3/191.6 kB 1.4 MB/s eta 0:00:01
#      -------------------------------------- 191.6/191.6 kB 1.3 MB/s eta 0:00:00
# Requirement already satisfied: h11>=0.8 in c:\users\sairam\anaconda3\envs\mlops\lib\site-packages (from uvicorn[standard]<1,>=0.14.0->feast) (0.14.0)
# Collecting httptools>=0.5.0
#   Using cached httptools-0.5.0-cp38-cp38-win_amd64.whl (144 kB)
# Collecting watchfiles>=0.13
#   Downloading watchfiles-0.19.0-cp37-abi3-win_amd64.whl (270 kB)
#      ---------------------------------------- 0.0/270.9 kB ? eta -:--:--
#      ---- ---------------------------------- 30.7/270.9 kB 1.3 MB/s eta 0:00:01
#      ------------- ------------------------- 92.2/270.9 kB 1.1 MB/s eta 0:00:01
#      ----------------- -------------------- 122.9/270.9 kB 1.0 MB/s eta 0:00:01
#      -------------------- --------------- 153.6/270.9 kB 919.0 kB/s eta 0:00:01
#      ------------------------- ---------- 194.6/270.9 kB 841.6 kB/s eta 0:00:01
#      ----------------------------- ------ 225.3/270.9 kB 860.2 kB/s eta 0:00:01
#      -----------------------------------  266.2/270.9 kB 862.0 kB/s eta 0:00:01
#      ------------------------------------ 270.9/270.9 kB 835.5 kB/s eta 0:00:00
# Requirement already satisfied: websockets>=10.4 in c:\users\sairam\anaconda3\envs\mlops\lib\site-packages (from uvicorn[standard]<1,>=0.14.0->feast) (11.0.3)
# Collecting python-dotenv>=0.13
#   Using cached python_dotenv-1.0.0-py3-none-any.whl (19 kB)
# Collecting fissix
#   Downloading fissix-21.11.13-py3-none-any.whl (188 kB)
#      ---------------------------------------- 0.0/188.3 kB ? eta -:--:--
#      ------ -------------------------------- 30.7/188.3 kB 1.4 MB/s eta 0:00:01
#      ------------ ------------------------ 61.4/188.3 kB 825.8 kB/s eta 0:00:01
#      --------------------- -------------- 112.6/188.3 kB 731.4 kB/s eta 0:00:01
#      ----------------------- ------------ 122.9/188.3 kB 722.1 kB/s eta 0:00:01
#      ----------------------------- ------ 153.6/188.3 kB 654.6 kB/s eta 0:00:01
#      ------------------------------------ 188.3/188.3 kB 633.7 kB/s eta 0:00:00
# Requirement already satisfied: attrs in c:\users\sairam\anaconda3\envs\mlops\lib\site-packages (from bowler->feast) (22.1.0)
# Collecting moreorless>=0.2.0
#   Downloading moreorless-0.4.0-py2.py3-none-any.whl (9.3 kB)
# Collecting volatile
#   Downloading volatile-2.1.0.tar.gz (3.3 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: importlib-resources>=1.4.0 in c:\users\sairam\anaconda3\envs\mlops\lib\site-packages (from jsonschema->feast) (5.2.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\sairam\anaconda3\envs\mlops\lib\site-packages (from jsonschema->feast) (0.18.0)
# Requirement already satisfied: pkgutil-resolve-name>=1.3.10 in c:\users\sairam\anaconda3\envs\mlops\lib\site-packages (from jsonschema->feast) (1.3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sairam\anaconda3\envs\mlops\lib\site-packages (from requests->feast) (1.26.16)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\sairam\anaconda3\envs\mlops\lib\site-packages (from requests->feast) (3.1.0)
# Requirement already satisfied: anyio<5.0,>=3.0 in c:\users\sairam\anaconda3\envs\mlops\lib\site-packages (from httpcore<0.18.0,>=0.15.0->httpx>=0.23.3->feast) (3.5.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\sairam\anaconda3\envs\mlops\lib\site-packages (from importlib-metadata>=4.13.0->dask>=2021.1.0->feast) (3.11.0)
# Requirement already satisfied: tomli>=1.1.0 in c:\users\sairam\anaconda3\envs\mlops\lib\site-packages (from mypy>=0.910->SQLAlchemy[mypy]<2,>1->feast) (2.0.1)
# Requirement already satisfied: mypy-extensions>=1.0.0 in c:\users\sairam\anaconda3\envs\mlops\lib\site-packages (from mypy>=0.910->SQLAlchemy[mypy]<2,>1->feast) (1.0.0)
# Requirement already satisfied: locket in c:\users\sairam\anaconda3\envs\mlops\lib\site-packages (from partd>=1.2.0->dask>=2021.1.0->feast) (1.0.0)
# Requirement already satisfied: appdirs in c:\users\sairam\anaconda3\envs\mlops\lib\site-packages (from fissix->bowler->feast) (1.4.4)
# Building wheels for collected packages: pandavro, volatile
#   Building wheel for pandavro (setup.py): started
#   Building wheel for pandavro (setup.py): finished with status 'done'
#   Created wheel for pandavro: filename=pandavro-1.5.2-py3-none-any.whl size=2942 sha256=47a7a52ade750cc262da67f2bed63c1e4b8386502c27f20795a03057af6aa288
#   Stored in directory: c:\users\sairam\appdata\local\pip\cache\wheels\21\03\ef\f7f69842521378eb3fd932bd3e13341e0b2c1617c56abc4da5
#   Building wheel for volatile (setup.py): started
#   Building wheel for volatile (setup.py): finished with status 'done'
#   Created wheel for volatile: filename=volatile-2.1.0-py3-none-any.whl size=3475 sha256=d7038277cba1db6c7d32e83b7f47c18b540536718b761856b51d93bd5760f550
#   Stored in directory: c:\users\sairam\appdata\local\pip\cache\wheels\0c\ef\7a\2eaf3bbba895518a953834e4ffd572d30ccd98900a253baea5
# Successfully built pandavro volatile
# Installing collected packages: volatile, mmh3, typeguard, sqlalchemy2-stubs, python-dotenv, proto-plus, mypy, httptools, grpcio, fissix, fastavro, dill, watchfiles, pandas, moreorless, grpcio-reflection, pandavro, bowler, feast
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.0.1
#     Uninstalling pandas-2.0.1:
#       Successfully uninstalled pandas-2.0.1
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'C:\\Users\\sairam\\anaconda3\\envs\\mlops\\Lib\\site-packages\\~-ndas\\_libs\\algos.cp38-win_amd64.pyd'
# Consider using the `--user` option or check the permissions.

# %%
# !feast version
# Out:
# Feast SDK Version: "feast 0.31.1"

# %% [markdown]
# # Do feast init

# %%
#this is option as it creates the feast repo directory structure. you can create a directory using mkdir and inside that create
#a feature_Store.yaml file and a feature_definitions.py file. but its better to use feast init and then modify the respective files.

# %%
# !feast init feature_repo
# Out:
# Creating a new Feast repository in C:\Users\sairam\Data Science\feature store\feature_repo.
# 06/13/2023 03:26:39 PM root INFO: copying C:\Users\sairam\anaconda3\envs\mlops\lib\site-packages\feast\templates\local\bootstrap.py -> C:\Users\sairam\Data Science\feature store\feature_repo
# 06/13/2023 03:26:39 PM root INFO: creating C:\Users\sairam\Data Science\feature store\feature_repo\feature_repo
# 06/13/2023 03:26:39 PM root INFO: copying C:\Users\sairam\anaconda3\envs\mlops\lib\site-packages\feast\templates\local\feature_repo\example_repo.py -> C:\Users\sairam\Data Science\feature store\feature_repo\feature_repo
# 06/13/2023 03:26:39 PM root INFO: copying C:\Users\sairam\anaconda3\envs\mlops\lib\site-packages\feast\templates\local\feature_repo\feature_store.yaml -> C:\Users\sairam\Data Science\feature store\feature_repo\feature_repo
# 06/13/2023 03:26:39 PM root INFO: copying C:\Users\sairam\anaconda3\envs\mlops\lib\site-packages\feast\templates\local\feature_repo\test_workflow.py -> C:\Users\sairam\Data Science\feature store\feature_repo\feature_repo
# 06/13/2023 03:26:39 PM root INFO: copying C:\Users\sairam\anaconda3\envs\mlops\lib\site-packages\feast\templates\local\feature_repo\__init__.py -> C:\Users\sairam\Data Science\feature store\feature_repo\feature_repo
# 06/13/2023 03:26:39 PM root INFO: creating C:\Users\sairam\Data Science\feature store\feature_repo\feature_repo\__pycache__
# 06/13/2023 03:26:39 PM root INFO: copying C:\Users\sairam\anaconda3\envs\mlops\lib\site-packages\feast\templates\local\feature_repo\__pycache__\example_repo.cpython-38.pyc -> C:\Users\sairam\Data Science\feature store\feature_repo\feature_repo\__pycache__
# 06/13/2023 03:26:39 PM root INFO: copying C:\Users\sairam\anaconda3\envs\mlops\lib\site-packages\feast\templates\local\feature_repo\__pycache__\test_workflow.cpython-38.pyc -> C:\Users\sairam\Data Science\feature store\feature_repo\feature_repo\__pycache__
# 06/13/2023 03:26:39 PM root INFO: copying C:\Users\sairam\anaconda3\envs\mlops\lib\site-packages\feast\templates\local\feature_repo\__pycache__\__init__.cpython-38.pyc -> C:\Users\sairam\Data Science\feature store\feature_repo\feature_repo\__pycache__
# 06/13/2023 03:26:39 PM root INFO: copying C:\Users\sairam\anaconda3\envs\mlops\lib\site-packages\feast\templates\local\README.md -> C:\Users\sairam\Data Science\feature store\feature_repo
# 06/13/2023 03:26:39 PM root INFO: copying C:\Users\sairam\anaconda3\envs\mlops\lib\site-packages\feast\templates\local\__init__.py -> C:\Users\sairam\Data Science\feature store\feature_repo
# 06/13/2023 03:26:39 PM root INFO: creating C:\Users\sairam\Data Science\feature store\feature_repo\__pycache__
# 06/13/2023 03:26:39 PM root INFO: copying C:\Users\sairam\anaconda3\envs\mlops\lib\site-packages\feast\templates\local\__pycache__\bootstrap.cpython-38.pyc -> C:\Users\sairam\Data Science\feature store\feature_repo\__pycache__
# 06/13/2023 03:26:39 PM root INFO: copying C:\Users\sairam\anaconda3\envs\mlops\lib\site-packages\feast\templates\local\__pycache__\__init__.cpython-38.pyc -> C:\Users\sairam\Data Science\feature store\feature_repo\__pycache__

# %% [markdown]
# # Update feature store yaml file if needed
#
# #you can update the online store and local store paths in feature_store.yaml file if needed.

# %% [markdown]
# # Define Feature definitions in a python file inside feature repo directory (created using feast init)
# This step is known as register and deploy the features go inside the feature_repo folder in the github you will see the feature_definition.py file with updated code. modify as per to your dataset features.

# %% [markdown]
# # Do feast apply
# do feast apply from inside the feature_repo directory

# %%
pwd
# Out:
# 'C:\\Users\\sairam\\Data Science\\feature store\\feature_repo'

# %%
cd feature_repo
# Out:
# C:\Users\sairam\Data Science\feature store\feature_repo\feature_repo

# %%
pwd
# Out:
# 'C:\\Users\\sairam\\Data Science\\feature store\\feature_repo\\feature_repo'

# %%
# !feast apply
# Out:
# Created entity patient_id
# Created feature view target_df_feature_view
# Created feature view predictors_df_feature_view
#
# Created sqlite table feature_repo_predictors_df_feature_view
# Created sqlite table feature_repo_target_df_feature_view

# %% [markdown]
# # Generate Training Data Set

# %%
from feast import FeatureStore
from feast.infra.offline_stores.file_source import SavedDatasetFileStorage

store = FeatureStore(repo_path='.')

entity_df = pd.read_parquet(path = 'data/target_df.parquet')

training_data = store.get_historical_features(
entity_df = entity_df,
    features = [
        "predictors_df_feature_view:Pregnancies",
        "predictors_df_feature_view:Glucose",
        "predictors_df_feature_view:BloodPressure",
        "predictors_df_feature_view:SkinThickness",
        "predictors_df_feature_view:Insulin",
        "predictors_df_feature_view:BMI",
        "predictors_df_feature_view:DiabetesPedigreeFunction",
        "predictors_df_feature_view:Age",
               ]
)

dataset = store.create_saved_dataset(
from_=training_data,
    name = "diabetes_dataset",
    storage = SavedDatasetFileStorage('data/diabetes_dataset.parquet')
)
# Out:
# C:\Users\sairam\anaconda3\envs\mlops\lib\site-packages\feast\feature_store.py:1177: RuntimeWarning: Saving dataset is an experimental feature. This API is unstable and it could and most probably will be changed in the future. We do not guarantee that future changes will maintain backward compatibility.
#   warnings.warn(

# %%
training_data.to_df()
# Out:
#      Outcome                  event_timestamp  patient_id  Pregnancies
# 0          0 2021-05-08 14:31:28.830917+00:00           0            1  \
# 1          1 2021-05-09 14:31:28.830917+00:00           1            8
# 2          0 2021-05-10 14:31:28.830917+00:00           2            1
# 3          1 2021-05-11 14:31:28.830917+00:00           3            0
# 4          0 2021-05-12 14:31:28.830917+00:00           4            5
# ..       ...                              ...         ...          ...
# 762        0 2023-06-09 14:31:28.830917+00:00         762           10
# 763        0 2023-06-10 14:31:28.830917+00:00         763            2
# 764        0 2023-06-11 14:31:28.830917+00:00         764            5
# 765        1 2023-06-12 14:31:28.830917+00:00         765            1
# 766        0 2023-06-13 14:31:28.830917+00:00         766            1
#
#      Glucose  BloodPressure  SkinThickness  Insulin   BMI
# 0         85             66             29        0  26.6  \
# 1        183             64              0        0  23.3
# 2         89             66             23       94  28.1
# 3        137             40             35      168  43.1
# 4        116             74              0        0  25.6
# ..       ...            ...            ...      ...   ...
# 762      101             76             48      180  32.9
# 763      122             70             27        0  36.8
# 764      121             72             23      112  26.2
# 765      126             60              0        0  30.1
# 766       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.351   31
# 1                       0.672   32
# 2                       0.167   21
# 3                       2.288   33
# 4                       0.201   30
# ..                        ...  ...
# 762                     0.171   63
# 763                     0.340   27
# 764                     0.245   30
# 765                     0.349   47
# 766                     0.315   23
#
# [767 rows x 11 columns]

# %% [markdown]
# # Model Training

# %%
# Importing dependencies
from feast import FeatureStore
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from joblib import dump

# Getting our FeatureStore
store = FeatureStore(repo_path=".")

# Retrieving the saved dataset and converting it to a DataFrame
training_df = store.get_saved_dataset(name="diabetes_dataset").to_df()

# Separating the features and labels
y = training_df['Outcome']
X = training_df.drop(
    labels=['Outcome', 'event_timestamp', "patient_id"], 
    axis=1)

# Splitting the dataset into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, 
                                                    y, 
                                                    stratify=y)

# Creating and training LogisticRegression
reg = LogisticRegression()
reg.fit(X=X_train[sorted(X_train)], y=y_train)

# Saving the model
dump(value=reg, filename="model.joblib")
# Out:
# C:\Users\sairam\anaconda3\envs\mlops\lib\site-packages\feast\feature_store.py:1230: RuntimeWarning: Retrieving datasets is an experimental feature. This API is unstable and it could and most probably will be changed in the future. We do not guarantee that future changes will maintain backward compatibility.
#   warnings.warn(
# C:\Users\sairam\anaconda3\envs\mlops\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# ['model.joblib']

# %% [markdown]
# # Prepare online feature store
# (Loading the features to online store)
#
# There are two ways you can use to load features to your online store
#
# materialize
# materialize loads the latest features between two dates.
#
# feast materialize 2020–01–01T00:00:00 2022–01–01T00:00:00
#
# materialize-incremental
# materialize-incremental loads features up to the provided end date:
#
# feast materialize-incremental 2022–01–01T00:00:00

# %%
# Importing dependencies
from feast import FeatureStore
from datetime import datetime, timedelta

# Getting our FeatureStore
store = FeatureStore(repo_path=".")

store.materialize_incremental(end_date = datetime.now())
# Out:
# Materializing 2 feature views to 2023-06-13 18:15:03+05:30 into the sqlite online store.
#
# target_df_feature_view from 2023-06-11 12:45:03+05:30 to 2023-06-13 18:15:03+05:30:
# 100%|████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 164.25it/s]
# predictors_df_feature_view from 2023-06-11 12:45:03+05:30 to 2023-06-13 23:45:03+05:30:
# 100%|████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 240.18it/s]

# %% [markdown]
# # Get online features for prediction

# %%
# Importing dependencies
from feast import FeatureStore
import pandas as pd
from joblib import load

# Getting our FeatureStore
store = FeatureStore(repo_path=".")

# Defining our features names
feast_features = [
        "predictors_df_feature_view:Pregnancies",
        "predictors_df_feature_view:Glucose",
        "predictors_df_feature_view:BloodPressure",
        "predictors_df_feature_view:SkinThickness",
        "predictors_df_feature_view:Insulin",
        "predictors_df_feature_view:BMI",
        "predictors_df_feature_view:DiabetesPedigreeFunction",
        "predictors_df_feature_view:Age",
    ]

# Getting the latest features
features = store.get_online_features(
    features=feast_features,    
    entity_rows=[{"patient_id": 765}, {"patient_id": 765}]
).to_dict()

# Converting the features to a DataFrame
features_df = pd.DataFrame.from_dict(data=features)

# %%
features_df.head()
# Out:
#    patient_id  BloodPressure  Pregnancies  Age  Insulin  Glucose
# 0         765             60            1   47        0      126  \
# 1         765             60            1   47        0      126
#
#    DiabetesPedigreeFunction   BMI  SkinThickness
# 0                     0.349  30.1              0
# 1                     0.349  30.1              0

# %% [markdown]
# # Call the predict function and see the output

# %%
# Loading our model and doing inference
reg = load("model.joblib")
predictions = reg.predict(features_df[sorted(features_df.drop("patient_id", axis=1))])
print(predictions)
# Out:
# [0 0]
